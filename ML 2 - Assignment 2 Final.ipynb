# %%
pip install mlxtend
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pathlib import Path
import heapq
from collections import defaultdict
import pandas as pd
import matplotlib.pylab as plt
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %%
fp_df = pd.read_csv('cosmetics.csv')
fp_df.set_index('Trns_#', inplace=True)
fp_df
# Out:
#         Bag  Blush  Nail_Polish  Brushes  Concealer  Eyebrow_Pencils  Bronzer
# Trns_#
# 1         0      1            1        1          1                0        1
# 2         0      0            1        0          1                0        1
# 3         0      1            0        0          1                1        1
# 4         0      0            1        1          1                0        1
# 5         0      1            0        0          1                0        1
# 6         0      0            0        0          1                0        0
# 7         0      1            1        1          1                0        1
# 8         0      0            1        1          0                0        1
# 9         0      0            0        0          1                0        0
# 10        1      1            1        1          0                0        0
# 11        0      0            1        0          0                0        1
# ...

# %%
itemsets = apriori(fp_df, min_support=0.5, use_colnames=True)
itemsets
# Out:
# C:\Users\mazah\anaconda3\lib\site-packages\mlxtend\frequent_patterns\fpcommon.py:111: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
#     support                itemsets
# 0  0.666667           (Nail_Polish)
# 1  0.500000               (Brushes)
# 2  0.750000             (Concealer)
# 3  0.750000               (Bronzer)
# 4  0.500000  (Brushes, Nail_Polish)
# 5  0.583333  (Bronzer, Nail_Polish)
# 6  0.583333    (Bronzer, Concealer)

# %%
rules = association_rules(itemsets, metric='confidence', min_threshold=0.5)
rules.sort_values(by=['lift'], ascending=False).head(6)
# Out:
#      antecedents    consequents  antecedent support  consequent support  \
# 0      (Brushes)  (Nail_Polish)            0.500000            0.666667
# 1  (Nail_Polish)      (Brushes)            0.666667            0.500000
# 2      (Bronzer)  (Nail_Polish)            0.750000            0.666667
# 3  (Nail_Polish)      (Bronzer)            0.666667            0.750000
# 4      (Bronzer)    (Concealer)            0.750000            0.750000
# 5    (Concealer)      (Bronzer)            0.750000            0.750000
#
#     support  confidence      lift  leverage  conviction
# 0  0.500000    1.000000  1.500000  0.166667         inf
# 1  0.500000    0.750000  1.500000  0.166667       2.000
# 2  0.583333    0.777778  1.166667  0.083333       1.500
# 3  0.583333    0.875000  1.166667  0.083333       2.000
# 4  0.583333    0.777778  1.037037  0.020833       1.125
# 5  0.583333    0.777778  1.037037  0.020833       1.125

# %%
print(rules.sort_values(by=['lift'], ascending=False).drop(columns=['antecedent support', 'consequent support', 'conviction'])
.head(6))
# Out:
#      antecedents    consequents   support  confidence      lift  leverage
# 0      (Brushes)  (Nail_Polish)  0.500000    1.000000  1.500000  0.166667
# 1  (Nail_Polish)      (Brushes)  0.500000    0.750000  1.500000  0.166667
# 2      (Bronzer)  (Nail_Polish)  0.583333    0.777778  1.166667  0.083333
# 3  (Nail_Polish)      (Bronzer)  0.583333    0.875000  1.166667  0.083333
# 4      (Bronzer)    (Concealer)  0.583333    0.777778  1.037037  0.020833
# 5    (Concealer)      (Bronzer)  0.583333    0.777778  1.037037  0.020833

# %%
rules[[len(c) == 1 for c in rules.consequents]].sort_values(by=['lift'],
ascending=False).head(6)
# Out:
#      antecedents    consequents  antecedent support  consequent support  \
# 0      (Brushes)  (Nail_Polish)            0.500000            0.666667
# 1  (Nail_Polish)      (Brushes)            0.666667            0.500000
# 2      (Bronzer)  (Nail_Polish)            0.750000            0.666667
# 3  (Nail_Polish)      (Bronzer)            0.666667            0.750000
# 4      (Bronzer)    (Concealer)            0.750000            0.750000
# 5    (Concealer)      (Bronzer)            0.750000            0.750000
#
#     support  confidence      lift  leverage  conviction
# 0  0.500000    1.000000  1.500000  0.166667         inf
# 1  0.500000    0.750000  1.500000  0.166667       2.000
# 2  0.583333    0.777778  1.166667  0.083333       1.500
# 3  0.583333    0.875000  1.166667  0.083333       2.000
# 4  0.583333    0.777778  1.037037  0.020833       1.125
# 5  0.583333    0.777778  1.037037  0.020833       1.125
